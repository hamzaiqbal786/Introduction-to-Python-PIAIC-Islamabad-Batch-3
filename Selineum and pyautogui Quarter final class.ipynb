# %% [markdown]
# # PyAutoGui
# - Control System GUI

# %%
import pyautogui as pg

# %%
pg.position()
# Out:
# Point(x=509, y=15)

# %%
pg.moveTo(509,15,4)

# %%
pg.click(509,15)

# %%
pg.moveTo(509,15,4)
pg.click()

# %%
pg.position()
# Out:
# Point(x=72, y=874)

# %%
pg.moveTo(509,15,4)
pg.click()

pg.moveTo(739,423,4)
pg.click()

pg.write("Hello World\n",interval=0.20)

# %%
pg.hotkey('winleft','left')

# %%
pg.size()
# Out:
# Size(width=1600, height=900)

# %%
pg.moveTo(72,874,4)
pg.click()
#pg.PAUSE()
pg.write("calculator\n",interval=0.20)

# %%
pg.alert(text='Transaction Succeed',title='Congratulation',button='Ok')
# Out:
# 'Ok'

# %%
btn = pg.confirm(text='',title='',buttons=['Ok','Cancle'])
if btn == 'Ok':
    print("You Selected file will be Deleted")
else:
    print("Deletion Canceled")
# Out:
# Deletion Canceled

# %% [markdown]
# # Beautiful Soft
# - Web Scrapping

# %%
import urllib
print(dir(urllib))
help(urllib)
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'error', 'parse', 'request', 'response']
# Help on package urllib:
#
# NAME
#     urllib
#
# PACKAGE CONTENTS
#     error
#     parse
#     request
#     response
#     robotparser
#
# FILE
#     c:\programdata\anaconda3\lib\urllib\__init__.py

# %%
from urllib.request import urlopen retrieve
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv'

# %%
from urllib.request import urlopen Request

url = 'http://www.gutenberg.org/files/10095/10095-h/10095-h.htm'
request = Request(url)
request.

# %%
from bs4 import BeautifulSoup
import requests
url = 'http://www.gutenberg.org/files/10095/10095-h/10095-h.htm'
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc)
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Garnett, Richard: The twilight of the gods</title>
# </head>
# <body>
# <pre>
#
# The Project Gutenberg EBook of The Twilight of the Gods, and Other Tales
# by Richard Garnett
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: The Twilight of the Gods, and Other Tales
#
# Author: Richard Garnett
#
# Release Date: November 16, 2003 [EBook #10095]
#
# Language: English
#
# Character set encoding: ISO-8859-1
#
# *** START OF THIS PROJECT GUTENBERG EBOOK TWILIGHT OF GODS ***
#
#
#
#
# Produced by Suzanne Shell and the Online Distributed Proofreading Team
#
#
#
#
#
# </pre>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Garnett, Richard: The twilight of the gods
#   </title>
#  </head>
#  <body>
#   <pre>
#
# The Project Gutenberg EBook of The Twilight of the Gods, and Other Tales
# by Richard Garnett
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: The Twilight of the Gods, and Other Tales
#
# Author: Richard Garnett
#
# Release Date: November 16, 2003 [EBook #10095]
#
# Language: English
#
# Character set encoding: ISO-8859-1
#
# *** START OF THIS PROJECT GUTENBERG EBOOK TWILIGHT OF GODS ***
#
#
#
#
# ...

# %%
print(soup.title)
print(type(soup.title))
soup.title.string
# Out:
# <title>Garnett, Richard: The twilight of the gods</title>
# <class 'bs4.element.Tag'>
# 'Garnett, Richard: The twilight of the gods'

# %%
print(soup.get_text())
# Out:
# Garnett, Richard: The twilight of the gods
#
#
#
#
# The Project Gutenberg EBook of The Twilight of the Gods, and Other Tales
# by Richard Garnett
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: The Twilight of the Gods, and Other Tales
#
# Author: Richard Garnett
#
# Release Date: November 16, 2003 [EBook #10095]
#
# Language: English
#
# Character set encoding: ISO-8859-1
#
# *** START OF THIS PROJECT GUTENBERG EBOOK TWILIGHT OF GODS ***
#
#
#
#
# Produced by Suzanne Shell and the Online Distributed Proofreading Team
#
#
#
#
#
#
#
# THE TWILIGHT
# OF THE GODS:
# AND OTHER TALES
#
# BY
#
# RICHARD GARNETT
# MDCCCCIII
#
#
#
#
#
# TO
# HORACE HOWARD FURNESS
# AND
# GEORG BRANDES.
# DABO DUOBUS TESTIBUS MEIS
#
#
# CONTENTS
#
# The Twilight of the Gods
# ...

# %% [markdown]
# # Selenium
# - Download web driver for each browser
# - Used for web Controlling

# %% [markdown]
# # PyQt5
# - Used for Dektop Development
